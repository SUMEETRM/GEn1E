# %%
import pandas as pd
high = pd.read_csv('temp_debug.csv')
high.head()
# Out:
#   county_smoking county_ascii_smoking county_full_smoking  \
# 0    Los Angeles          Los Angeles  Los Angeles County
# 1           Cook                 Cook         Cook County
# 2           Cook                 Cook         Cook County
# 3           Cook                 Cook         Cook County
# 4         Harris               Harris       Harris County
#
#    county_fips_smoking state_id_smoking  state_name      lat       lng  \
# 0                 6037               CA  California  34.3209 -118.2247
# 1                17031               IL    Illinois  41.8401  -87.8168
# 2                17031               IL    Illinois  41.8401  -87.8168
# 3                17031               IL    Illinois  41.8401  -87.8168
# 4                48201               TX       Texas  29.8577  -95.3936
#
#    population_smoking  id_smoking  ...       county  county_ascii_y  \
# 0            10019635           1  ...  Los Angeles     Los Angeles
# 1             5265398           2  ...         Cook            Cook
# 2             5265398           2  ...         Cook            Cook
# 3             5265398           2  ...         Cook            Cook
# 4             4697957           3  ...       Harris          Harris
#
#         county_full_y  county_fips_y state_id_y  population_y  id_y  \
# 0  Los Angeles County           6037         CA      10019635     1
# 1         Cook County          17031         IL       5265398     2
# 2         Cook County          17031         IL       5265398     2
# 3         Cook County          17031         IL       5265398     2
# 4       Harris County          48201         TX       4697957     3
#
#   normalized_incomes Unnamed: 0 normalized_health_insurance
# 0           0.825178      205.0                    0.202046
# 1           0.944783      611.0                    0.204604
# 2           0.828830      611.0                    0.204604
# 3           0.870279      611.0                    0.204604
# 4           0.883322     2624.0                    0.514066
#
# [5 rows x 65 columns]

# %%
high['normalized_smoking'].max()
# Out:
# 1.0

# %%
combined_data['combined_weighted_value'] = (
        storeweights[0] * combined_data['normalized_smoking'] 
        + storeweights[1] * combined_data['normalized_copd']
        + storeweights[2] * combined_data['normalized_covid']
        + storeweights[3] * combined_data['normalized_drowning']
        + storeweights[4] * combined_data['normalized_sepsis']
        + storeweights[5] * combined_data['normalized_flu']
        + storeweights[6] * combined_data['normalized_pneumonia']
        + storeweights[7] * combined_data['normalized_vaccination']
        + storeweights[8] * combined_data['normalized_literacy']
        + storeweights[9] * combined_data['normalized_incomes']
        + storeweights[10] * combined_data['normalized_seniors']
        + storeweights[11] * combined_data['normalized_health_insurance']
    )

# %%
#Messed up
#Drowning
#Covid
#flu
mind = high['normalized_drowning'] .min()
maxd  = high['normalized_drowning'] .max()
high['normalized_drowning'] = (high['normalized_drowning']  - mind)/(maxd-mind)
high['normalized_drowning'].max()
# Out:
# 1.0
